# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Import customer table
path_customers = r'/Users/janekobtseva/10-10-2025 Brazilian E-Commerce Public Dataset/02 Data/Original Data/olist_customers_dataset.csv'

# %%
df_customers = pd.read_csv(os.path.join(path_customers), index_col = False)

# %%
df_customers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
df_customers.describe()
# Out:
#        customer_zip_code_prefix
# count              99441.000000
# mean               35137.474583
# std                29797.938996
# min                 1003.000000
# 25%                11347.000000
# 50%                24416.000000
# 75%                58900.000000
# max                99990.000000

# %%
#Finding Missing Values

df_customers.isnull().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
#look for full duplicates within your dataframe:
df_dups_customer = df_customers[df_customers.duplicated()]

# %%
df_dups_customer
# Out:
# Empty DataFrame
# Columns: [customer_id, customer_unique_id, customer_zip_code_prefix, customer_city, customer_state]
# Index: []

# %%
#Check for mixed-type data in your df_ords dataframe

for col in df_customers.columns.tolist():
  weird = (df_customers[[col]].applymap(type) != df_customers[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_customers[weird]) > 0:
    print (col)
# Out:
# /var/folders/13/1jb5kb0d14783hy2x_n_wdrm0000gn/T/ipykernel_30594/3541805868.py:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_customers[[col]].applymap(type) != df_customers[[col]].iloc[0].apply(type)).any(axis = 1)
# /var/folders/13/1jb5kb0d14783hy2x_n_wdrm0000gn/T/ipykernel_30594/3541805868.py:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_customers[[col]].applymap(type) != df_customers[[col]].iloc[0].apply(type)).any(axis = 1)
# /var/folders/13/1jb5kb0d14783hy2x_n_wdrm0000gn/T/ipykernel_30594/3541805868.py:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_customers[[col]].applymap(type) != df_customers[[col]].iloc[0].apply(type)).any(axis = 1)
# /var/folders/13/1jb5kb0d14783hy2x_n_wdrm0000gn/T/ipykernel_30594/3541805868.py:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
# ...

# %%
# Import olist_geolocation_dataset table
path_geolocation = r'/Users/janekobtseva/10-10-2025 Brazilian E-Commerce Public Dataset/02 Data/Original Data/olist_geolocation_dataset.csv'

# %%
df_geolocation = pd.read_csv(os.path.join(path_geolocation), index_col = False)

# %%
df_geolocation.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
#Finding Missing Values

df_geolocation.isnull().sum()
# Out:
# geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# geolocation_state              0
# dtype: int64

# %%
#look for full duplicates
#Ido not see duplicates
df_dups_geolocation = df_geolocation[df_geolocation.duplicated()]

# %%
df_dups_geolocation
# Out:
#          geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 15                              1046       -23.546081       -46.644820
# 44                              1046       -23.546081       -46.644820
# 65                              1046       -23.546081       -46.644820
# 66                              1009       -23.546935       -46.636588
# 67                              1046       -23.546081       -46.644820
# ...                              ...              ...              ...
# 1000153                        99970       -28.343273       -51.873734
# 1000154                        99950       -28.070493       -52.011342
# 1000159                        99900       -27.877125       -52.224882
# 1000160                        99950       -28.071855       -52.014716
# 1000162                        99950       -28.070104       -52.018658
#
#         geolocation_city geolocation_state
# 15             sao paulo                SP
# ...

# %%
df_geolocation['geolocation_city'].value_counts(dropna = False)
# Out:
# geolocation_city
# sao paulo               135800
# rio de janeiro           62151
# belo horizonte           27805
# são paulo                24918
# curitiba                 16593
#                          ...
# jacuípe                      1
# mar vermelho                 1
# quebrangulo                  1
# poço das trincheiras         1
# poxim                        1
# Name: count, Length: 8011, dtype: int64

# %%
df_geolocation['geolocation_state'].value_counts(dropna = False)
# Out:
# geolocation_state
# SP    404268
# MG    126336
# RJ    121169
# RS     61851
# PR     57859
# SC     38328
# BA     36045
# GO     20139
# ES     16748
# PE     16432
# DF     12986
# MT     12031
# CE     11674
# PA     10853
# MS     10431
# MA      7853
# PB      5538
# RN      5041
# PI      4549
# AL      4183
# TO      3576
# SE      3563
# RO      3478
# AM      2432
# AC      1301
# AP       853
# RR       646
# Name: count, dtype: int64

# %%
#Check for mixed-type data in your df_ords dataframe

for col in df_geolocation.columns.tolist():
  weird = (df_geolocation[[col]].applymap(type) != df_geolocation[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_geolocation[weird]) > 0:
    print (col)
# Out:
# /var/folders/13/1jb5kb0d14783hy2x_n_wdrm0000gn/T/ipykernel_30594/789574568.py:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_geolocation[[col]].applymap(type) != df_geolocation[[col]].iloc[0].apply(type)).any(axis = 1)
# /var/folders/13/1jb5kb0d14783hy2x_n_wdrm0000gn/T/ipykernel_30594/789574568.py:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_geolocation[[col]].applymap(type) != df_geolocation[[col]].iloc[0].apply(type)).any(axis = 1)
# /var/folders/13/1jb5kb0d14783hy2x_n_wdrm0000gn/T/ipykernel_30594/789574568.py:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_geolocation[[col]].applymap(type) != df_geolocation[[col]].iloc[0].apply(type)).any(axis = 1)
# /var/folders/13/1jb5kb0d14783hy2x_n_wdrm0000gn/T/ipykernel_30594/789574568.py:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
# ...

# %%
df_geolocation.describe()
# Out:
#        geolocation_zip_code_prefix  geolocation_lat  geolocation_lng
# count                 1.000163e+06     1.000163e+06     1.000163e+06
# mean                  3.657417e+04    -2.117615e+01    -4.639054e+01
# std                   3.054934e+04     5.715866e+00     4.269748e+00
# min                   1.001000e+03    -3.660537e+01    -1.014668e+02
# 25%                   1.107500e+04    -2.360355e+01    -4.857317e+01
# 50%                   2.653000e+04    -2.291938e+01    -4.663788e+01
# 75%                   6.350400e+04    -1.997962e+01    -4.376771e+01
# max                   9.999000e+04     4.506593e+01     1.211054e+02

# %%
# Import order_items table
path_order_items = r'/Users/janekobtseva/10-10-2025 Brazilian E-Commerce Public Dataset/02 Data/Original Data/olist_order_items_dataset.csv'

# %%
df_order_items = pd.read_csv(os.path.join(path_order_items), index_col = False)

# %%
df_order_items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
#Finding Missing Values

df_order_items.isnull().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %%
#look for full duplicates 
df_dups_order_items = df_order_items[df_order_items.duplicated()]

# %%
df_dups_order_items
# Out:
# Empty DataFrame
# Columns: [order_id, order_item_id, product_id, seller_id, shipping_limit_date, price, freight_value]
# Index: []

# %%
#Check for mixed-type data 

for col in df_order_items.columns.tolist():
  weird = (df_order_items[[col]].applymap(type) != df_order_items[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_order_items[weird]) > 0:
    print (col)
# Out:
# /var/folders/13/1jb5kb0d14783hy2x_n_wdrm0000gn/T/ipykernel_30594/2402058341.py:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_order_items[[col]].applymap(type) != df_order_items[[col]].iloc[0].apply(type)).any(axis = 1)
# /var/folders/13/1jb5kb0d14783hy2x_n_wdrm0000gn/T/ipykernel_30594/2402058341.py:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_order_items[[col]].applymap(type) != df_order_items[[col]].iloc[0].apply(type)).any(axis = 1)
# /var/folders/13/1jb5kb0d14783hy2x_n_wdrm0000gn/T/ipykernel_30594/2402058341.py:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_order_items[[col]].applymap(type) != df_order_items[[col]].iloc[0].apply(type)).any(axis = 1)
# /var/folders/13/1jb5kb0d14783hy2x_n_wdrm0000gn/T/ipykernel_30594/2402058341.py:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
# ...

# %%
df_order_items.describe()
# Out:
#        order_item_id          price  freight_value
# count  112650.000000  112650.000000  112650.000000
# mean        1.197834     120.653739      19.990320
# std         0.705124     183.633928      15.806405
# min         1.000000       0.850000       0.000000
# 25%         1.000000      39.900000      13.080000
# 50%         1.000000      74.990000      16.260000
# 75%         1.000000     134.900000      21.150000
# max        21.000000    6735.000000     409.680000

# %%
# Import payments table
path_payments = r'/Users/janekobtseva/10-10-2025 Brazilian E-Commerce Public Dataset/02 Data/Original Data/olist_order_payments_dataset.csv'

# %%
df_payments = pd.read_csv(os.path.join(path_payments), index_col = False)

# %%
df_payments.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
#Finding Missing Values

df_payments.isnull().sum()
# Out:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %%
#look for full duplicates 
df_dups_payments = df_payments[df_payments.duplicated()]

# %%
df_dups_payments
# Out:
# Empty DataFrame
# Columns: [order_id, payment_sequential, payment_type, payment_installments, payment_value]
# Index: []

# %%
#Check for mixed-type data 

for col in df_payments.columns.tolist():
  weird = (df_payments[[col]].applymap(type) != df_payments[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_payments[weird]) > 0:
    print (col)
# Out:
# /var/folders/13/1jb5kb0d14783hy2x_n_wdrm0000gn/T/ipykernel_30594/4027249208.py:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_payments[[col]].applymap(type) != df_payments[[col]].iloc[0].apply(type)).any(axis = 1)
# /var/folders/13/1jb5kb0d14783hy2x_n_wdrm0000gn/T/ipykernel_30594/4027249208.py:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_payments[[col]].applymap(type) != df_payments[[col]].iloc[0].apply(type)).any(axis = 1)
# /var/folders/13/1jb5kb0d14783hy2x_n_wdrm0000gn/T/ipykernel_30594/4027249208.py:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_payments[[col]].applymap(type) != df_payments[[col]].iloc[0].apply(type)).any(axis = 1)
# /var/folders/13/1jb5kb0d14783hy2x_n_wdrm0000gn/T/ipykernel_30594/4027249208.py:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
# ...

# %%
df_payments.describe()
# Out:
#        payment_sequential  payment_installments  payment_value
# count       103886.000000         103886.000000  103886.000000
# mean             1.092679              2.853349     154.100380
# std              0.706584              2.687051     217.494064
# min              1.000000              0.000000       0.000000
# 25%              1.000000              1.000000      56.790000
# 50%              1.000000              1.000000     100.000000
# 75%              1.000000              4.000000     171.837500
# max             29.000000             24.000000   13664.080000

# %%
# Import olist_order_reviews_dataset table
path_order_reviews = r'/Users/janekobtseva/10-10-2025 Brazilian E-Commerce Public Dataset/02 Data/Original Data/olist_order_reviews_dataset.csv'

# %%
df_order_reviews = pd.read_csv(os.path.join(path_order_reviews), index_col = False)

# %%
df_order_reviews.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %%
#Finding Missing Values
# because review score is not missing, I decided to ignore missing values for title and messages

df_order_reviews.isnull().sum()
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %%
#look for full duplicates 
df_dups_order_reviews = df_order_reviews[df_order_reviews.duplicated()]

# %%
df_dups_order_reviews
# Out:
# Empty DataFrame
# Columns: [review_id, order_id, review_score, review_comment_title, review_comment_message, review_creation_date, review_answer_timestamp]
# Index: []

# %%
#Check for mixed-type data 

for col in df_order_reviews.columns.tolist():
  weird = (df_order_reviews[[col]].applymap(type) != df_order_reviews[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_order_reviews[weird]) > 0:
    print (col)
# Out:
# review_comment_title
# review_comment_message
# /var/folders/13/1jb5kb0d14783hy2x_n_wdrm0000gn/T/ipykernel_30594/2737633093.py:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_order_reviews[[col]].applymap(type) != df_order_reviews[[col]].iloc[0].apply(type)).any(axis = 1)
# /var/folders/13/1jb5kb0d14783hy2x_n_wdrm0000gn/T/ipykernel_30594/2737633093.py:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_order_reviews[[col]].applymap(type) != df_order_reviews[[col]].iloc[0].apply(type)).any(axis = 1)
# /var/folders/13/1jb5kb0d14783hy2x_n_wdrm0000gn/T/ipykernel_30594/2737633093.py:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_order_reviews[[col]].applymap(type) != df_order_reviews[[col]].iloc[0].apply(type)).any(axis = 1)
# ...

# %%
df_order_reviews.describe()
# Out:
#        review_score
# count  99224.000000
# mean       4.086421
# std        1.347579
# min        1.000000
# 25%        4.000000
# 50%        5.000000
# 75%        5.000000
# max        5.000000

# %%
# Import orders table
path_order = r'/Users/janekobtseva/10-10-2025 Brazilian E-Commerce Public Dataset/02 Data/Original Data/olist_orders_dataset.csv'

# %%
df_order = pd.read_csv(os.path.join(path_order), index_col = False)

# %%
df_order.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
#Finding Missing Values
#order_delivered_customer_date - decided to delete all these rows, as it means that order was not delivered to the customer. 
#thus the order was not completed, meaning that we cannot have a review here 

df_order.isnull().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
df_nan=df_order[df_order['order_delivered_customer_date'].isnull()==True]

# %%
df_nan.head(50)
# Out:
#                               order_id                       customer_id  \
# 6     136cce7faa42fdb2cefd53fdc79a6098  ed0271e0b7da060a393796590e7b737a
# 44    ee64d42b8cf066f35eac1cf57de1aa85  caded193e8e47b8362864762a83db3c5
# 103   0760a852e4e9d89eb77bf631eaaf1c84  d2a79636084590b7465af8ab374a8cf5
# 128   15bed8e2fec7fdbadb186b57c46c92f2  f3f0e613e0bdb9c7cee75504f0f90679
# 154   6942b8da583c2f9957e990d028607019  52006a9383bf149a4fb24226b173106f
# 162   36530871a5e80138db53bcfd8a104d90  4dafe3c841d2d6cc8a8b6d25b35704b9
# 231   4d630f57194f5aba1a3d12ce23e71cd9  6d491c9fe2f04f6e2af6ec033cd8907c
# 266   8e24261a7e58791d10cb1bf9da94df5c  64a254d30eed42cd0e6c36dddb88adf0
# 299   3b4ad687e7e5190db827e1ae5a8989dd  1a87b8517b7d31373b50396eb15cb445
# 305   b68d69564a79dea4776afa33d1d2fcab  de1e5517fb50896bbdcff5814fb31802
# 324   d3c8851a6651eeff2f73b0e011ac45d0  957f8e082185574de25992dc659ebbc0
# 333   f373335aac9a659de916f7170b8bc07a  f06a94a401e52fb019c72f2e8bbf6a2f
# ...

# %%
df_order.shape
# Out:
# (99441, 8)

# %%
#cleaning data
df_order_clean = df_order[df_order['order_delivered_customer_date'].isnull() == False]

# %%
df_order_clean.shape
# Out:
# (96476, 8)

# %%
#look for full duplicates 
df_dups_order_clean = df_order_clean[df_order_clean.duplicated()]

# %%
df_dups_order_clean
# Out:
# Empty DataFrame
# Columns: [order_id, customer_id, order_status, order_purchase_timestamp, order_approved_at, order_delivered_carrier_date, order_delivered_customer_date, order_estimated_delivery_date]
# Index: []

# %%
#Check for mixed-type data 

for col in df_order_clean.columns.tolist():
  weird = (df_order_clean[[col]].applymap(type) != df_order_clean[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_order_clean[weird]) > 0:
    print (col)
# Out:
# order_approved_at
# order_delivered_carrier_date
# /var/folders/13/1jb5kb0d14783hy2x_n_wdrm0000gn/T/ipykernel_30594/984233741.py:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_order_clean[[col]].applymap(type) != df_order_clean[[col]].iloc[0].apply(type)).any(axis = 1)
# /var/folders/13/1jb5kb0d14783hy2x_n_wdrm0000gn/T/ipykernel_30594/984233741.py:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_order_clean[[col]].applymap(type) != df_order_clean[[col]].iloc[0].apply(type)).any(axis = 1)
# /var/folders/13/1jb5kb0d14783hy2x_n_wdrm0000gn/T/ipykernel_30594/984233741.py:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_order_clean[[col]].applymap(type) != df_order_clean[[col]].iloc[0].apply(type)).any(axis = 1)
# ...

# %%
df_order_clean.describe()
# Out:
#                                 order_id                       customer_id  \
# count                              96476                             96476
# unique                             96476                             96476
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
#
#        order_status order_purchase_timestamp    order_approved_at  \
# count         96476                    96476                96462
# unique            2                    95954                88273
# top       delivered      2018-06-01 13:39:44  2018-02-27 04:31:10
# freq          96470                        3                    9
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# count                         96475                         96476
# unique                        80112                         95664
# ...

# %%
# Import products_dataset table
path_products = r'/Users/janekobtseva/10-10-2025 Brazilian E-Commerce Public Dataset/02 Data/Original Data/olist_products_dataset.csv'

# %%
df_products = pd.read_csv(os.path.join(path_products), index_col = False)

# %%
df_products.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
#Finding Missing Values
#I decided to delete product_category_name+product_name_lenght+product_description_lenght+product_photos_qty, as it would be hard to identify 
#and understand which product are we talking about 
#procuct description (product_weight_g), I decided to ignore

df_products.isnull().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
df_nan_products=df_products[df_products['product_category_name'].isnull()==True]

# %%
df_nan_products
# Out:
#                              product_id product_category_name  \
# 105    a41e356c76fab66334f36de622ecbd3a                   NaN
# 128    d8dee61c2034d6d075997acef1870e9b                   NaN
# 145    56139431d72cd51f19eb9f7dae4d1617                   NaN
# 154    46b48281eb6d663ced748f324108c733                   NaN
# 197    5fb61f482620cb672f5e586bb132eae9                   NaN
# ...                                 ...                   ...
# 32515  b0a0c5dd78e644373b199380612c350a                   NaN
# 32589  10dbe0fbaa2c505123c17fdc34a63c56                   NaN
# 32616  bd2ada37b58ae94cc838b9c0569fecd8                   NaN
# 32772  fa51e914046aab32764c41356b9d4ea4                   NaN
# 32852  c4ceee876c82b8328e9c293fa0e1989b                   NaN
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 105                    NaN                         NaN                 NaN
# ...

# %%
df_products.shape
# Out:
# (32951, 9)

# %%
#cleaning data
df_products_clean = df_products[df_products['product_category_name'].isnull() == False]

# %%
df_products_clean.shape
# Out:
# (32341, 9)

# %%
df_products_clean.isnull().sum()
# Out:
# product_id                    0
# product_category_name         0
# product_name_lenght           0
# product_description_lenght    0
# product_photos_qty            0
# product_weight_g              1
# product_length_cm             1
# product_height_cm             1
# product_width_cm              1
# dtype: int64

# %%
#look for full duplicates 
df_dups_df_products_clean = df_products_clean[df_products_clean.duplicated()]

# %%
df_dups_df_products_clean
# Out:
# Empty DataFrame
# Columns: [product_id, product_category_name, product_name_lenght, product_description_lenght, product_photos_qty, product_weight_g, product_length_cm, product_height_cm, product_width_cm]
# Index: []

# %%
#Check for mixed-type data 

for col in df_products_clean.columns.tolist():
  weird = (df_products_clean[[col]].applymap(type) != df_products_clean[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_products_clean[weird]) > 0:
    print (col)
# Out:
# /var/folders/13/1jb5kb0d14783hy2x_n_wdrm0000gn/T/ipykernel_30594/2377790471.py:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_products_clean[[col]].applymap(type) != df_products_clean[[col]].iloc[0].apply(type)).any(axis = 1)
# /var/folders/13/1jb5kb0d14783hy2x_n_wdrm0000gn/T/ipykernel_30594/2377790471.py:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_products_clean[[col]].applymap(type) != df_products_clean[[col]].iloc[0].apply(type)).any(axis = 1)
# /var/folders/13/1jb5kb0d14783hy2x_n_wdrm0000gn/T/ipykernel_30594/2377790471.py:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_products_clean[[col]].applymap(type) != df_products_clean[[col]].iloc[0].apply(type)).any(axis = 1)
# ...

# %%
df_products_clean.describe()
# Out:
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# count         32341.000000                32341.000000        32341.000000
# mean             48.476949                  771.495285            2.188986
# std              10.245741                  635.115225            1.736766
# min               5.000000                    4.000000            1.000000
# 25%              42.000000                  339.000000            1.000000
# 50%              51.000000                  595.000000            1.000000
# 75%              57.000000                  972.000000            3.000000
# max              76.000000                 3992.000000           20.000000
#
#        product_weight_g  product_length_cm  product_height_cm  \
# count      32340.000000       32340.000000       32340.000000
# mean        2276.956586          30.854545          16.958813
# std         4279.291845          16.955965          13.636115
# ...

# %%
# Import seller table
path_seller = r'/Users/janekobtseva/10-10-2025 Brazilian E-Commerce Public Dataset/02 Data/Original Data/olist_sellers_dataset.csv'

# %%
df_seller = pd.read_csv(os.path.join(path_seller), index_col = False)

# %%
df_seller.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %%
#Finding Missing Values

df_seller.isnull().sum()
# Out:
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64

# %%
#look for full duplicates 
df_dups_seller = df_seller[df_seller.duplicated()]

# %%
df_dups_seller
# Out:
# Empty DataFrame
# Columns: [seller_id, seller_zip_code_prefix, seller_city, seller_state]
# Index: []

# %%
#Check for mixed-type data 

for col in df_seller.columns.tolist():
  weird = (df_seller[[col]].applymap(type) != df_seller[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_seller[weird]) > 0:
    print (col)
# Out:
# /var/folders/13/1jb5kb0d14783hy2x_n_wdrm0000gn/T/ipykernel_30594/1127618566.py:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_seller[[col]].applymap(type) != df_seller[[col]].iloc[0].apply(type)).any(axis = 1)
# /var/folders/13/1jb5kb0d14783hy2x_n_wdrm0000gn/T/ipykernel_30594/1127618566.py:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_seller[[col]].applymap(type) != df_seller[[col]].iloc[0].apply(type)).any(axis = 1)
# /var/folders/13/1jb5kb0d14783hy2x_n_wdrm0000gn/T/ipykernel_30594/1127618566.py:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_seller[[col]].applymap(type) != df_seller[[col]].iloc[0].apply(type)).any(axis = 1)
# /var/folders/13/1jb5kb0d14783hy2x_n_wdrm0000gn/T/ipykernel_30594/1127618566.py:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
# ...

# %%
df_seller.describe()
# Out:
#        seller_zip_code_prefix
# count             3095.000000
# mean             32291.059451
# std              32713.453830
# min               1001.000000
# 25%               7093.500000
# 50%              14940.000000
# 75%              64552.500000
# max              99730.000000

# %%
# Import seller table
path_product_category_name = r'/Users/janekobtseva/10-10-2025 Brazilian E-Commerce Public Dataset/02 Data/Original Data/product_category_name_translation.csv'

# %%
df_product_category_name = pd.read_csv(os.path.join(path_product_category_name), index_col = False)

# %%
df_product_category_name.head(10)
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor
# 5           esporte_lazer                sports_leisure
# 6              perfumaria                     perfumery
# 7   utilidades_domesticas                    housewares
# 8               telefonia                     telephony
# 9      relogios_presentes                 watches_gifts

# %%
#Finding Missing Values

df_product_category_name.isnull().sum()
# Out:
# product_category_name            0
# product_category_name_english    0
# dtype: int64

# %%
#look for full duplicates 
df_dups_product_category_name = df_product_category_name[df_product_category_name.duplicated()]

# %%
df_dups_product_category_name
# Out:
# Empty DataFrame
# Columns: [product_category_name, product_category_name_english]
# Index: []

# %%
#Check for mixed-type data 

for col in df_product_category_name.columns.tolist():
  weird = (df_product_category_name[[col]].applymap(type) != df_product_category_name[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_product_category_name[weird]) > 0:
    print (col)
# Out:
# /var/folders/13/1jb5kb0d14783hy2x_n_wdrm0000gn/T/ipykernel_30594/3506959674.py:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_product_category_name[[col]].applymap(type) != df_product_category_name[[col]].iloc[0].apply(type)).any(axis = 1)
# /var/folders/13/1jb5kb0d14783hy2x_n_wdrm0000gn/T/ipykernel_30594/3506959674.py:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_product_category_name[[col]].applymap(type) != df_product_category_name[[col]].iloc[0].apply(type)).any(axis = 1)

# %%
df_product_category_name.describe()
# Out:
#        product_category_name product_category_name_english
# count                     71                            71
# unique                    71                            71
# top             beleza_saude                 health_beauty
# freq                       1                             1

# %%
#Export your final and cleaned files 

path_prepared_data = r'/Users/janekobtseva/10-10-2025 Brazilian E-Commerce Public Dataset/02 Data/Prepared Data'

# %%
df_order_clean.to_csv(os.path.join(path_prepared_data,'df_order_clean.csv'))

# %%
df_products_clean.to_csv(os.path.join(path_prepared_data,'df_products_clean.csv'))
